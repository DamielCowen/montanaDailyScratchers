# %%
import pandas as pd
from bs4 import BeautifulSoup
from datetime import datetime

# %%
def htmlToGames(html_file):
    '''
    input: path to .html file
    returns: bs4 result set of games on page
    
    reads html file from montana state lottery website daily scrathers pages and returns bs4 result set of games
    '''
    with open(html_file, 'r') as file:
        soup = BeautifulSoup(file, 'lxml')
    games_soup = soup.find("div",{"class":"col-md-12 bgw"}) #isolates the center column of page where all the games are
    games = games_soup.findAll("div",{"class":"row scratch-game pad50 mg0"}) #divides the games into a bs4 result set
    return games

def gamesToList(games_in):
    out = []
    today = datetime.today().strftime('%Y-%m-%d')
    for gameTag in games_in:
        out.append({"name":getGameName(gameTag),"date":today,"data":getGameData(gameTag)})
    return out

def getGameName(gameTag):
    return gameTag.find("span",{"scratch-game-title cr-main text-uppercase pull-left" }).text

def cleanCells(cells):
    out = {}
    for cell in cells:
        out[str(cell).split('data-bind="text: ')[1].split('"')[0]]=cell.text
    return out

def getGameData(gameTag):
    out = []
    rows = gameTag.tbody.findAll("tr")
    for row in rows[:-1]:
        cells = row.findAll("td")
        out.append(cleanCells(cells))
    out.append({'overall odds': rows[-1].text.split()[2]})
    
    return out
    
        
    
    
final = gamesToList(games)

# %%
one_dollar_games = htmlToGames('data/20210406_one_dollar.html')
one_list = gamesToList(one_dollar_games)
one_list
# Out:
# [{'name': '3-2-Won!',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.14'},
#    {'win': '$1 w/ DBLR', 'prize': '$2', 'odds': '1:50.00'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:50.00'},
#    {'win': '$5', 'prize': '$5', 'odds': '1:66.67'},
#    {'win': '$5 w/ DBLR', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$5 x 3', 'prize': '$15', 'odds': '1:400.00'},
#    {'win': '$15', 'prize': '$15', 'odds': '1:400.00'},
#    {'win': '$5 x 4', 'prize': '$20', 'odds': '1:1,428.57'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:2,000.00'},
#    {'win': '$20 w/ DBLR + $10', 'prize': '$50', 'odds': '1:1,176.47'},
#    {'win': '$50', 'prize': '$50', 'odds': '1:5,000.00'},
#    {'win': '$50 w/ DBLR', 'prize': '$100', 'odds': '1:10,000.00'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:20,000.00'},
#    {'win': '$1,500', 'prize': '$1,500', 'odds': '1:110,000.00'},
#    {'overall odds': '4.71'}]},
#  {'name': 'Gnome Me The Money',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.69'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:17.39'},
#    {'win': '$5', 'prize': '$5', 'odds': '1:66.67'},
#    {'win': '$5 x 2', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:666.67'},
#    {'win': '$5 x 4', 'prize': '$20', 'odds': '1:1,333.33'},
#    {'win': '$40', 'prize': '$40', 'odds': '1:1,666.67'},
#    {'win': '$10 x 4', 'prize': '$40', 'odds': '1:1,333.33'},
#    {'win': '($40 x 2) + ($10 x 2)', 'prize': '$100', 'odds': '1:4,000.00'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:4,000.00'},
#    {'win': '$1,000', 'prize': '$1,000', 'odds': '1:110,000.00'},
#    {'overall odds': '4.62'}]},
#  {'name': 'Lucky Roll',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.69'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:18.18'},
#    {'win': '$5', 'prize': '$5', 'odds': '1:100.00'},
#    {'win': '$5 w/DOUBLE', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$10 w/DOUBLE', 'prize': '$20', 'odds': '1:571.43'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:1,000.00'},
#    {'win': '$20 w/DOUBLE', 'prize': '$40', 'odds': '1:571.43'},
#    {'win': '$40', 'prize': '$40', 'odds': '1:2,000.00'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:4,000.00'},
#    {'win': '$2,000', 'prize': '$2,000', 'odds': '1:110,000.00'},
#    {'overall odds': '4.76'}]},
#  {'name': 'Lucky Spot',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.69'},
#    {'win': '$1 x 2', 'prize': '$2', 'odds': '1:33.33'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:50.00'},
#    {'win': '($2 x 2) + $1', 'prize': '$5', 'odds': '1:100.00'},
#    {'win': '$5', 'prize': '$5', 'odds': '1:100.00'},
#    {'win': '$5 x 2', 'prize': '$10', 'odds': '1:400.00'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:400.00'},
#    {'win': '$5 x 4', 'prize': '$20', 'odds': '1:333.33'},
#    {'win': '$10 x 2', 'prize': '$20', 'odds': '1:333.33'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:666.67'},
#    {'win': '($20 x 2) + ($5 x 2)', 'prize': '$50', 'odds': '1:3,333.33'},
#    {'win': '$50', 'prize': '$50', 'odds': '1:3,333.33'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:20,000.00'},
#    {'win': '$1,000', 'prize': '$1,000', 'odds': '1:73,333.33'},
#    {'overall odds': '4.69'}]},
#  {'name': 'Merry Christmas',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:6.25'},
#    {'win': '$2', 'prize': '$1', 'odds': '1:21.05'},
#    {'win': '$5', 'prize': '$5', 'odds': '1:66.67'},
#    {'win': '$5 x 2', 'prize': '$10', 'odds': '1:133.33'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:133.33'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:1,052.63'},
#    {'win': '$5 x 4', 'prize': '$20', 'odds': '1:1,052:63'},
#    {'win': '$40', 'prize': '$40', 'odds': '1:4,000.00'},
#    {'win': '($5 x 4) + ($10 x 2)', 'prize': '$40', 'odds': '1:4,000.00'},
#    {'win': '($20 x 4) + ($10 x 2)', 'prize': '$100', 'odds': '1:8,000.00'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:8,000.00'},
#    {'win': '$1,000', 'prize': '$1,000', 'odds': '1:60,000.00'},
#    {'overall odds': '4.16'}]},
#  {'name': 'Snow Days',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.14'},
#    {'win': '$1 x 2', 'prize': '$2', 'odds': '1:50.00'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:50.00'},
#    {'win': '$5', 'prize': '$5', 'odds': '1:66.67'},
#    {'win': '$5 x 2', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$5 + $10', 'prize': '$15', 'odds': '1:400.00'},
#    {'win': '$15', 'prize': '$15', 'odds': '1:400.00'},
#    {'win': '$5 x 4', 'prize': '$20', 'odds': '1:1,000.00'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:1,333.33'},
#    {'win': '$10 x 5', 'prize': '$50', 'odds': '1:4,000.00'},
#    {'win': '$50', 'prize': '$50', 'odds': '1:4,000.00'},
#    {'win': '$50 x 2', 'prize': '$100', 'odds': '1:20,000.00'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:20,000.00'},
#    {'win': '$1,500', 'prize': '$1,500', 'odds': '1:60,000.00'},
#    {'overall odds': '4.71'}]},
#  {'name': 'E-I-E-I DOUGH',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.69'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:18.18'},
#    {'win': '$5', 'prize': '$5', 'odds': '1:100.00'},
#    {'win': '$10 w/TRACTOR', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$20 w/TRACTOR', 'prize': '$20', 'odds': '1:500.00'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:1,000.00'},
#    {'win': '$50 w/TRACTOR', 'prize': '$50', 'odds': '1:740.74'},
#    {'win': '$50', 'prize': '$50', 'odds': '1:2,857.14'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:2,857.14'},
#    {'win': '$1,000', 'prize': '$1,000', 'odds': '1:110,000.00'},
#    {'overall odds': '4.76'}]},
#  {'name': 'Crossword Express',
#   'date': '2021-04-07',
#   'data': [{'win': '2 Words', 'prize': '$1', 'odds': '1:5.26'},
#    {'win': '3 Words', 'prize': '$3', 'odds': '1:25.00'},
#    {'win': '4 Words', 'prize': '$12', 'odds': '1:50.00'},
#    {'win': '5 Words', 'prize': '$40', 'odds': '1:6,666.67'},
#    {'win': '6 Words', 'prize': '$1,000', 'odds': '1:110,000.00'},
#    {'overall odds': '1:4.00'}]},
#  {'name': "Super Hot 7's",
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.69'},
#    {'win': '$1 x 2', 'prize': '$2', 'odds': '1:25.00'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:25.00'},
#    {'win': '($2 x 3) + $1', 'prize': '$7', 'odds': '1:80.00'},
#    {'win': '$7', 'prize': '$7', 'odds': '1:80.00'},
#    {'win': '($7 x 2) + $2 + $1', 'prize': '$17', 'odds': '1:400.00'},
#    {'win': '$17', 'prize': '$17', 'odds': '1:400.00'},
#    {'win': '($7 x 3) + ($2 x 3)', 'prize': '$27', 'odds': '1:2,000.00'},
#    {'win': '$27', 'prize': '$27', 'odds': '1:2,000.00'},
#    {'win': '$70', 'prize': '$70', 'odds': '1:8,000.00'},
#    {'win': '$7,777', 'prize': '$7,777', 'odds': '1:160,000.00'},
#    {'overall odds': '4.15'}]},
#  {'name': 'Cash Dash',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.69'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:18.18'},
#    {'win': '$5', 'prize': '$5', 'odds': '1:100.00'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:100.00'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:444.44'},
#    {'win': '$50', 'prize': '$50', 'odds': '1:1,000.00'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:1,333.33'},
#    {'win': '$2,000', 'prize': '$2,000', 'odds': '1:110,000.00'},
#    {'overall odds': '4.78'}]},
#  {'name': 'Fast Money',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.14'},
#    {'win': '$1 x 2', 'prize': '$2', 'odds': '1:50.00'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:50.00'},
#    {'win': 'Fast Bonus Game: $5', 'prize': '$5', 'odds': '1:66.67'},
#    {'win': '$5 x 2', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': 'Fast Bonus Game: $10', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$5 + $10', 'prize': '$15', 'odds': '1:400.00'},
#    {'win': '$15', 'prize': '$15', 'odds': '1:400.00'},
#    {'win': 'Fast Bonus Game: $20', 'prize': '$20', 'odds': '1:666.67'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:2,000.00'},
#    {'win': '$10 x 5', 'prize': '$50', 'odds': '1:1,818.18'},
#    {'win': '$50', 'prize': '$50', 'odds': '1:4,000.00'},
#    {'win': '$20 x 5', 'prize': '$100', 'odds': '1:10,000.00'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:20,000.00'},
#    {'win': '$1,500', 'prize': '$1,500', 'odds': '1:110,000.00'},
#    {'overall odds': '4.70'}]},
#  {'name': "Super HOT 7's",
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.69'},
#    {'win': '$1 x 2', 'prize': '$2', 'odds': '1:25.00'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:25.00'},
#    {'win': '($2 x 3) + $1', 'prize': '$7', 'odds': '1:80.00'},
#    {'win': '$7', 'prize': '$7', 'odds': '1:80.00'},
#    {'win': '($7 x 2) + $2 + $1', 'prize': '$17', 'odds': '1:400.00'},
#    {'win': '$17', 'prize': '$17', 'odds': '1:400.00'},
#    {'win': '($7 x 3) + ($2 x 3)', 'prize': '$27', 'odds': '1:1,250.00'},
#    {'win': '$27', 'prize': '$27', 'odds': '1:1,304.35'},
#    {'win': '$70', 'prize': '$70', 'odds': '1:6,000.00'},
#    {'win': '$5,000', 'prize': '$5,000', 'odds': '1:180,000.00'},
#    {'overall odds': '4.14'}]},
#  {'name': 'Fish & Chips',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.69'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:17.39'},
#    {'win': '$5', 'prize': '$5', 'odds': '1:66.67'},
#    {'win': '$5 x 2', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:666.67'},
#    {'win': '$5 x 4', 'prize': '$20', 'odds': '1:1,333.33'},
#    {'win': '$40', 'prize': '$40', 'odds': '1:1,666.67'},
#    {'win': '$10 x 4', 'prize': '$40', 'odds': '1:1,333.33'},
#    {'win': '($40 x 2) + ($10 x 2)', 'prize': '$100', 'odds': '1:4,000.00'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:4,000.00'},
#    {'win': '$1,000', 'prize': '$1,000', 'odds': '1:110,000.00'},
#    {'overall odds': '4.62'}]},
#  {'name': 'PAYDAY',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.69'},
#    {'win': '$1 w/Doubler', 'prize': '$2', 'odds': '1:33.33'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:50.00'},
#    {'win': '$1 x 5', 'prize': '$5', 'odds': '1:100.00'},
#    {'win': '$2 w/Doubler + $1', 'prize': '$5', 'odds': '1:100.00'},
#    {'win': '$5 w/Doubler', 'prize': '$10', 'odds': '1:400.00'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:400.00'},
#    {'win': '$10 w/Doubler', 'prize': '$20', 'odds': '1:333.33'},
#    {'win': '$5 w/Doubler + $10', 'prize': '$20', 'odds': '1:333.33'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:666.67'},
#    {'win': '$10 x 5', 'prize': '$50', 'odds': '1:3,333.33'},
#    {'win': '$50', 'prize': '$50', 'odds': '1:3,333.33'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:20,000.00'},
#    {'win': '$1,500', 'prize': '$1,500', 'odds': '1:110,000.00'},
#    {'overall odds': '4.69'}]},
#  {'name': 'DEUCES WILD',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.69'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:17.39'},
#    {'win': '$5', 'prize': '$5', 'odds': '1:66.67'},
#    {'win': '$5 w/2', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:1,333.33'},
#    {'win': '$10 w/2', 'prize': '$20', 'odds': '1:666.67'},
#    {'win': '$40', 'prize': '$40', 'odds': '1:1,666.67'},
#    {'win': '$10 x 4', 'prize': '$40', 'odds': '1:1,666.67'},
#    {'win': '$50 w/2', 'prize': '$100', 'odds': '1:2,857.14'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:6,666.67'},
#    {'win': '$2,000', 'prize': '$2,000', 'odds': '1:110,000.00'},
#    {'overall odds': '4.62'}]},
#  {'name': 'Moose Money',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.69'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:18.18'},
#    {'win': '$5', 'prize': '$5', 'odds': '1:100.00'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:100.00'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:400.00'},
#    {'win': '$50', 'prize': '$50', 'odds': '1:909.09'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:1,333.33'},
#    {'win': '$1,000', 'prize': '$1,000', 'odds': '1:110,000.00'},
#    {'overall odds': '4.78'}]}]

# %%
twenty_dollar_games = htmlToGames('data/20210406_twenty_dollar.html')
twenty_dollar = gamesToList(twenty_dollar_games)
twenty_dollar
# Out:
# [{'name': '3-2-Won!',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.14'},
#    {'win': '$1 w/ DBLR', 'prize': '$2', 'odds': '1:50.00'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:50.00'},
#    {'win': '$5', 'prize': '$5', 'odds': '1:66.67'},
#    {'win': '$5 w/ DBLR', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$5 x 3', 'prize': '$15', 'odds': '1:400.00'},
#    {'win': '$15', 'prize': '$15', 'odds': '1:400.00'},
#    {'win': '$5 x 4', 'prize': '$20', 'odds': '1:1,428.57'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:2,000.00'},
#    {'win': '$20 w/ DBLR + $10', 'prize': '$50', 'odds': '1:1,176.47'},
#    {'win': '$50', 'prize': '$50', 'odds': '1:5,000.00'},
#    {'win': '$50 w/ DBLR', 'prize': '$100', 'odds': '1:10,000.00'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:20,000.00'},
#    {'win': '$1,500', 'prize': '$1,500', 'odds': '1:110,000.00'},
#    {'overall odds': '4.71'}]},
#  {'name': 'Gnome Me The Money',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.69'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:17.39'},
#    {'win': '$5', 'prize': '$5', 'odds': '1:66.67'},
#    {'win': '$5 x 2', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:666.67'},
#    {'win': '$5 x 4', 'prize': '$20', 'odds': '1:1,333.33'},
#    {'win': '$40', 'prize': '$40', 'odds': '1:1,666.67'},
#    {'win': '$10 x 4', 'prize': '$40', 'odds': '1:1,333.33'},
#    {'win': '($40 x 2) + ($10 x 2)', 'prize': '$100', 'odds': '1:4,000.00'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:4,000.00'},
#    {'win': '$1,000', 'prize': '$1,000', 'odds': '1:110,000.00'},
#    {'overall odds': '4.62'}]},
#  {'name': 'Lucky Roll',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.69'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:18.18'},
#    {'win': '$5', 'prize': '$5', 'odds': '1:100.00'},
#    {'win': '$5 w/DOUBLE', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$10 w/DOUBLE', 'prize': '$20', 'odds': '1:571.43'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:1,000.00'},
#    {'win': '$20 w/DOUBLE', 'prize': '$40', 'odds': '1:571.43'},
#    {'win': '$40', 'prize': '$40', 'odds': '1:2,000.00'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:4,000.00'},
#    {'win': '$2,000', 'prize': '$2,000', 'odds': '1:110,000.00'},
#    {'overall odds': '4.76'}]},
#  {'name': 'Lucky Spot',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.69'},
#    {'win': '$1 x 2', 'prize': '$2', 'odds': '1:33.33'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:50.00'},
#    {'win': '($2 x 2) + $1', 'prize': '$5', 'odds': '1:100.00'},
#    {'win': '$5', 'prize': '$5', 'odds': '1:100.00'},
#    {'win': '$5 x 2', 'prize': '$10', 'odds': '1:400.00'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:400.00'},
#    {'win': '$5 x 4', 'prize': '$20', 'odds': '1:333.33'},
#    {'win': '$10 x 2', 'prize': '$20', 'odds': '1:333.33'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:666.67'},
#    {'win': '($20 x 2) + ($5 x 2)', 'prize': '$50', 'odds': '1:3,333.33'},
#    {'win': '$50', 'prize': '$50', 'odds': '1:3,333.33'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:20,000.00'},
#    {'win': '$1,000', 'prize': '$1,000', 'odds': '1:73,333.33'},
#    {'overall odds': '4.69'}]},
#  {'name': 'Merry Christmas',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:6.25'},
#    {'win': '$2', 'prize': '$1', 'odds': '1:21.05'},
#    {'win': '$5', 'prize': '$5', 'odds': '1:66.67'},
#    {'win': '$5 x 2', 'prize': '$10', 'odds': '1:133.33'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:133.33'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:1,052.63'},
#    {'win': '$5 x 4', 'prize': '$20', 'odds': '1:1,052:63'},
#    {'win': '$40', 'prize': '$40', 'odds': '1:4,000.00'},
#    {'win': '($5 x 4) + ($10 x 2)', 'prize': '$40', 'odds': '1:4,000.00'},
#    {'win': '($20 x 4) + ($10 x 2)', 'prize': '$100', 'odds': '1:8,000.00'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:8,000.00'},
#    {'win': '$1,000', 'prize': '$1,000', 'odds': '1:60,000.00'},
#    {'overall odds': '4.16'}]},
#  {'name': 'Snow Days',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.14'},
#    {'win': '$1 x 2', 'prize': '$2', 'odds': '1:50.00'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:50.00'},
#    {'win': '$5', 'prize': '$5', 'odds': '1:66.67'},
#    {'win': '$5 x 2', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$5 + $10', 'prize': '$15', 'odds': '1:400.00'},
#    {'win': '$15', 'prize': '$15', 'odds': '1:400.00'},
#    {'win': '$5 x 4', 'prize': '$20', 'odds': '1:1,000.00'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:1,333.33'},
#    {'win': '$10 x 5', 'prize': '$50', 'odds': '1:4,000.00'},
#    {'win': '$50', 'prize': '$50', 'odds': '1:4,000.00'},
#    {'win': '$50 x 2', 'prize': '$100', 'odds': '1:20,000.00'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:20,000.00'},
#    {'win': '$1,500', 'prize': '$1,500', 'odds': '1:60,000.00'},
#    {'overall odds': '4.71'}]},
#  {'name': 'E-I-E-I DOUGH',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.69'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:18.18'},
#    {'win': '$5', 'prize': '$5', 'odds': '1:100.00'},
#    {'win': '$10 w/TRACTOR', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$20 w/TRACTOR', 'prize': '$20', 'odds': '1:500.00'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:1,000.00'},
#    {'win': '$50 w/TRACTOR', 'prize': '$50', 'odds': '1:740.74'},
#    {'win': '$50', 'prize': '$50', 'odds': '1:2,857.14'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:2,857.14'},
#    {'win': '$1,000', 'prize': '$1,000', 'odds': '1:110,000.00'},
#    {'overall odds': '4.76'}]},
#  {'name': 'Crossword Express',
#   'date': '2021-04-07',
#   'data': [{'win': '2 Words', 'prize': '$1', 'odds': '1:5.26'},
#    {'win': '3 Words', 'prize': '$3', 'odds': '1:25.00'},
#    {'win': '4 Words', 'prize': '$12', 'odds': '1:50.00'},
#    {'win': '5 Words', 'prize': '$40', 'odds': '1:6,666.67'},
#    {'win': '6 Words', 'prize': '$1,000', 'odds': '1:110,000.00'},
#    {'overall odds': '1:4.00'}]},
#  {'name': "Super Hot 7's",
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.69'},
#    {'win': '$1 x 2', 'prize': '$2', 'odds': '1:25.00'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:25.00'},
#    {'win': '($2 x 3) + $1', 'prize': '$7', 'odds': '1:80.00'},
#    {'win': '$7', 'prize': '$7', 'odds': '1:80.00'},
#    {'win': '($7 x 2) + $2 + $1', 'prize': '$17', 'odds': '1:400.00'},
#    {'win': '$17', 'prize': '$17', 'odds': '1:400.00'},
#    {'win': '($7 x 3) + ($2 x 3)', 'prize': '$27', 'odds': '1:2,000.00'},
#    {'win': '$27', 'prize': '$27', 'odds': '1:2,000.00'},
#    {'win': '$70', 'prize': '$70', 'odds': '1:8,000.00'},
#    {'win': '$7,777', 'prize': '$7,777', 'odds': '1:160,000.00'},
#    {'overall odds': '4.15'}]},
#  {'name': 'Cash Dash',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.69'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:18.18'},
#    {'win': '$5', 'prize': '$5', 'odds': '1:100.00'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:100.00'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:444.44'},
#    {'win': '$50', 'prize': '$50', 'odds': '1:1,000.00'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:1,333.33'},
#    {'win': '$2,000', 'prize': '$2,000', 'odds': '1:110,000.00'},
#    {'overall odds': '4.78'}]},
#  {'name': 'Fast Money',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.14'},
#    {'win': '$1 x 2', 'prize': '$2', 'odds': '1:50.00'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:50.00'},
#    {'win': 'Fast Bonus Game: $5', 'prize': '$5', 'odds': '1:66.67'},
#    {'win': '$5 x 2', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': 'Fast Bonus Game: $10', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$5 + $10', 'prize': '$15', 'odds': '1:400.00'},
#    {'win': '$15', 'prize': '$15', 'odds': '1:400.00'},
#    {'win': 'Fast Bonus Game: $20', 'prize': '$20', 'odds': '1:666.67'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:2,000.00'},
#    {'win': '$10 x 5', 'prize': '$50', 'odds': '1:1,818.18'},
#    {'win': '$50', 'prize': '$50', 'odds': '1:4,000.00'},
#    {'win': '$20 x 5', 'prize': '$100', 'odds': '1:10,000.00'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:20,000.00'},
#    {'win': '$1,500', 'prize': '$1,500', 'odds': '1:110,000.00'},
#    {'overall odds': '4.70'}]},
#  {'name': "Super HOT 7's",
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.69'},
#    {'win': '$1 x 2', 'prize': '$2', 'odds': '1:25.00'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:25.00'},
#    {'win': '($2 x 3) + $1', 'prize': '$7', 'odds': '1:80.00'},
#    {'win': '$7', 'prize': '$7', 'odds': '1:80.00'},
#    {'win': '($7 x 2) + $2 + $1', 'prize': '$17', 'odds': '1:400.00'},
#    {'win': '$17', 'prize': '$17', 'odds': '1:400.00'},
#    {'win': '($7 x 3) + ($2 x 3)', 'prize': '$27', 'odds': '1:1,250.00'},
#    {'win': '$27', 'prize': '$27', 'odds': '1:1,304.35'},
#    {'win': '$70', 'prize': '$70', 'odds': '1:6,000.00'},
#    {'win': '$5,000', 'prize': '$5,000', 'odds': '1:180,000.00'},
#    {'overall odds': '4.14'}]},
#  {'name': 'Fish & Chips',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.69'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:17.39'},
#    {'win': '$5', 'prize': '$5', 'odds': '1:66.67'},
#    {'win': '$5 x 2', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:666.67'},
#    {'win': '$5 x 4', 'prize': '$20', 'odds': '1:1,333.33'},
#    {'win': '$40', 'prize': '$40', 'odds': '1:1,666.67'},
#    {'win': '$10 x 4', 'prize': '$40', 'odds': '1:1,333.33'},
#    {'win': '($40 x 2) + ($10 x 2)', 'prize': '$100', 'odds': '1:4,000.00'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:4,000.00'},
#    {'win': '$1,000', 'prize': '$1,000', 'odds': '1:110,000.00'},
#    {'overall odds': '4.62'}]},
#  {'name': 'PAYDAY',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.69'},
#    {'win': '$1 w/Doubler', 'prize': '$2', 'odds': '1:33.33'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:50.00'},
#    {'win': '$1 x 5', 'prize': '$5', 'odds': '1:100.00'},
#    {'win': '$2 w/Doubler + $1', 'prize': '$5', 'odds': '1:100.00'},
#    {'win': '$5 w/Doubler', 'prize': '$10', 'odds': '1:400.00'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:400.00'},
#    {'win': '$10 w/Doubler', 'prize': '$20', 'odds': '1:333.33'},
#    {'win': '$5 w/Doubler + $10', 'prize': '$20', 'odds': '1:333.33'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:666.67'},
#    {'win': '$10 x 5', 'prize': '$50', 'odds': '1:3,333.33'},
#    {'win': '$50', 'prize': '$50', 'odds': '1:3,333.33'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:20,000.00'},
#    {'win': '$1,500', 'prize': '$1,500', 'odds': '1:110,000.00'},
#    {'overall odds': '4.69'}]},
#  {'name': 'DEUCES WILD',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.69'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:17.39'},
#    {'win': '$5', 'prize': '$5', 'odds': '1:66.67'},
#    {'win': '$5 w/2', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:200.00'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:1,333.33'},
#    {'win': '$10 w/2', 'prize': '$20', 'odds': '1:666.67'},
#    {'win': '$40', 'prize': '$40', 'odds': '1:1,666.67'},
#    {'win': '$10 x 4', 'prize': '$40', 'odds': '1:1,666.67'},
#    {'win': '$50 w/2', 'prize': '$100', 'odds': '1:2,857.14'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:6,666.67'},
#    {'win': '$2,000', 'prize': '$2,000', 'odds': '1:110,000.00'},
#    {'overall odds': '4.62'}]},
#  {'name': 'Moose Money',
#   'date': '2021-04-07',
#   'data': [{'win': '$1', 'prize': '$1', 'odds': '1:7.69'},
#    {'win': '$2', 'prize': '$2', 'odds': '1:18.18'},
#    {'win': '$5', 'prize': '$5', 'odds': '1:100.00'},
#    {'win': '$10', 'prize': '$10', 'odds': '1:100.00'},
#    {'win': '$20', 'prize': '$20', 'odds': '1:400.00'},
#    {'win': '$50', 'prize': '$50', 'odds': '1:909.09'},
#    {'win': '$100', 'prize': '$100', 'odds': '1:1,333.33'},
#    {'win': '$1,000', 'prize': '$1,000', 'odds': '1:110,000.00'},
#    {'overall odds': '4.78'}]}]

# %%
rows =games[0].tbody.findAll("tr")
rows
# Out:
# [<tr>
#  <td class="text-center" data-bind="text: win">$1</td>
#  <td class="text-center cr-main" data-bind="text: prize">$1</td>
#  <td class="text-center" data-bind="text: odds">1:7.14</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$1 w/ DBLR</td>
#  <td class="text-center cr-main" data-bind="text: prize">$2</td>
#  <td class="text-center" data-bind="text: odds">1:50.00</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$2</td>
#  <td class="text-center cr-main" data-bind="text: prize">$2</td>
#  <td class="text-center" data-bind="text: odds">1:50.00</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$5</td>
#  <td class="text-center cr-main" data-bind="text: prize">$5</td>
#  <td class="text-center" data-bind="text: odds">1:66.67</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$5 w/ DBLR</td>
#  <td class="text-center cr-main" data-bind="text: prize">$10</td>
#  <td class="text-center" data-bind="text: odds">1:200.00</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$10</td>
#  <td class="text-center cr-main" data-bind="text: prize">$10</td>
#  <td class="text-center" data-bind="text: odds">1:200.00</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$5 x 3</td>
#  <td class="text-center cr-main" data-bind="text: prize">$15</td>
#  <td class="text-center" data-bind="text: odds">1:400.00</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$15</td>
#  <td class="text-center cr-main" data-bind="text: prize">$15</td>
#  <td class="text-center" data-bind="text: odds">1:400.00</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$5 x 4</td>
#  <td class="text-center cr-main" data-bind="text: prize">$20</td>
#  <td class="text-center" data-bind="text: odds">1:1,428.57</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$20</td>
#  <td class="text-center cr-main" data-bind="text: prize">$20</td>
#  <td class="text-center" data-bind="text: odds">1:2,000.00</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$20 w/ DBLR + $10</td>
#  <td class="text-center cr-main" data-bind="text: prize">$50</td>
#  <td class="text-center" data-bind="text: odds">1:1,176.47</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$50</td>
#  <td class="text-center cr-main" data-bind="text: prize">$50</td>
#  <td class="text-center" data-bind="text: odds">1:5,000.00</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$50 w/ DBLR</td>
#  <td class="text-center cr-main" data-bind="text: prize">$100</td>
#  <td class="text-center" data-bind="text: odds">1:10,000.00</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$100</td>
#  <td class="text-center cr-main" data-bind="text: prize">$100</td>
#  <td class="text-center" data-bind="text: odds">1:20,000.00</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$1,500</td>
#  <td class="text-center cr-main" data-bind="text: prize">$1,500</td>
#  <td class="text-center" data-bind="text: odds">1:110,000.00</td>
#  </tr>,
#  <tr>
#  <td class="text-center text-uppercase overall-odds" colspan="3" data-bind="visible: odds.overallOdds, html: 'Overall Odds '+odds.overallOdds">Overall Odds 4.71</td>
#  </tr>]

# %%
rows[-1].text.split()[2]
# Out:
# '4.71'

# %%
for cell in cells:
    print({str(cell).split('data-bind="text: ')[1].split('"')[0]:cell.text})
# Out:
# {'win': '$1'}
# {'prize': '$1'}
# {'odds': '1:7.14'}

# %%
rows[0].findAll(string='data-blind')
# Out:
# []

# %%
games[0].select('tr')
# Out:
# [<tr>
#  <th class="text-center text-uppercase">Win</th>
#  <th class="text-center text-uppercase cr-main">Prize</th>
#  <th class="text-center text-uppercase">Odds</th>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$1</td>
#  <td class="text-center cr-main" data-bind="text: prize">$1</td>
#  <td class="text-center" data-bind="text: odds">1:7.14</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$1 w/ DBLR</td>
#  <td class="text-center cr-main" data-bind="text: prize">$2</td>
#  <td class="text-center" data-bind="text: odds">1:50.00</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$2</td>
#  <td class="text-center cr-main" data-bind="text: prize">$2</td>
#  <td class="text-center" data-bind="text: odds">1:50.00</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$5</td>
#  <td class="text-center cr-main" data-bind="text: prize">$5</td>
#  <td class="text-center" data-bind="text: odds">1:66.67</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$5 w/ DBLR</td>
#  <td class="text-center cr-main" data-bind="text: prize">$10</td>
#  <td class="text-center" data-bind="text: odds">1:200.00</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$10</td>
#  <td class="text-center cr-main" data-bind="text: prize">$10</td>
#  <td class="text-center" data-bind="text: odds">1:200.00</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$5 x 3</td>
#  <td class="text-center cr-main" data-bind="text: prize">$15</td>
#  <td class="text-center" data-bind="text: odds">1:400.00</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$15</td>
#  <td class="text-center cr-main" data-bind="text: prize">$15</td>
#  <td class="text-center" data-bind="text: odds">1:400.00</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$5 x 4</td>
#  <td class="text-center cr-main" data-bind="text: prize">$20</td>
#  <td class="text-center" data-bind="text: odds">1:1,428.57</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$20</td>
#  <td class="text-center cr-main" data-bind="text: prize">$20</td>
#  <td class="text-center" data-bind="text: odds">1:2,000.00</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$20 w/ DBLR + $10</td>
#  <td class="text-center cr-main" data-bind="text: prize">$50</td>
#  <td class="text-center" data-bind="text: odds">1:1,176.47</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$50</td>
#  <td class="text-center cr-main" data-bind="text: prize">$50</td>
#  <td class="text-center" data-bind="text: odds">1:5,000.00</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$50 w/ DBLR</td>
#  <td class="text-center cr-main" data-bind="text: prize">$100</td>
#  <td class="text-center" data-bind="text: odds">1:10,000.00</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$100</td>
#  <td class="text-center cr-main" data-bind="text: prize">$100</td>
#  <td class="text-center" data-bind="text: odds">1:20,000.00</td>
#  </tr>,
#  <tr>
#  <td class="text-center" data-bind="text: win">$1,500</td>
#  <td class="text-center cr-main" data-bind="text: prize">$1,500</td>
#  <td class="text-center" data-bind="text: odds">1:110,000.00</td>
#  </tr>,
#  <tr>
#  <td class="text-center text-uppercase overall-odds" colspan="3" data-bind="visible: odds.overallOdds, html: 'Overall Odds '+odds.overallOdds">Overall Odds 4.71</td>
#  </tr>]

# %%
str(cells[0]).split('data-bind="text: ')[1].split('"')[0],cells[0].text
# Out:
# ('win', '$1')

# %%
games = htmlToGames("data/20210406_one_dollar.html")

x = 0
for g in games:
    print(g)
    print("*"*20)
    x+=1
    
x
# Out:
# <div class="row scratch-game pad50 mg0">
# <div class="col-md-12 mgb20 pd0">
# <span class="text-uppercase bold new pull-left" data-bind="visible: isNewGame == 1" style="display: none;"> New!</span>
# <span class="scratch-game-title cr-main text-uppercase pull-left" data-bind="html: gameName">3-2-Won!</span>
# </div>
# <div class="col-md-6 left">
# <div class="scratch-game-img-container mgb20" data-bind="if:visibleImage()!=''">
# <img alt="3-2-Won" data-bind="click: imageFaceToggle, attr: { src: visibleImage, alt: name }" src="/static/assets/1176_front.png"/>
# </div>
# <label class="cr-main font15 text-uppercase mgb10 pointer" data-bind="click: imageFaceToggle">CLICK FOR TICKET BACK</label>
# <div class="scratch-game-description" data-bind="html: howToPlay"><p>Reveal 2 like symbols in the same GAME, win prize shown for that GAME! Reveal 3 like symbols in the same GAME, win DOUBLE the prize shown for that GAME!</p>
# </div>
# </div>
# <!-- GAME ODDS -->
# <div class="col-md-6 pd0">
# <table>
# <thead class="bgg-secondary">
# <tr>
# <th class="text-center text-uppercase">Win</th>
# <th class="text-center text-uppercase cr-main">Prize</th>
# <th class="text-center text-uppercase">Odds</th>
# </tr>
# </thead>
# <tbody>
# <!-- ko foreach: odds.gameTable -->
# <tr>
# <td class="text-center" data-bind="text: win">$1</td>
# <td class="text-center cr-main" data-bind="text: prize">$1</td>
# <td class="text-center" data-bind="text: odds">1:7.14</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$1 w/ DBLR</td>
# <td class="text-center cr-main" data-bind="text: prize">$2</td>
# <td class="text-center" data-bind="text: odds">1:50.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$2</td>
# <td class="text-center cr-main" data-bind="text: prize">$2</td>
# <td class="text-center" data-bind="text: odds">1:50.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5</td>
# <td class="text-center cr-main" data-bind="text: prize">$5</td>
# <td class="text-center" data-bind="text: odds">1:66.67</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5 w/ DBLR</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:200.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:200.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5 x 3</td>
# <td class="text-center cr-main" data-bind="text: prize">$15</td>
# <td class="text-center" data-bind="text: odds">1:400.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$15</td>
# <td class="text-center cr-main" data-bind="text: prize">$15</td>
# <td class="text-center" data-bind="text: odds">1:400.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5 x 4</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:1,428.57</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$20</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:2,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$20 w/ DBLR + $10</td>
# <td class="text-center cr-main" data-bind="text: prize">$50</td>
# <td class="text-center" data-bind="text: odds">1:1,176.47</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$50</td>
# <td class="text-center cr-main" data-bind="text: prize">$50</td>
# <td class="text-center" data-bind="text: odds">1:5,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$50 w/ DBLR</td>
# <td class="text-center cr-main" data-bind="text: prize">$100</td>
# <td class="text-center" data-bind="text: odds">1:10,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$100</td>
# <td class="text-center cr-main" data-bind="text: prize">$100</td>
# <td class="text-center" data-bind="text: odds">1:20,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$1,500</td>
# <td class="text-center cr-main" data-bind="text: prize">$1,500</td>
# <td class="text-center" data-bind="text: odds">1:110,000.00</td>
# </tr>
# <!-- /ko -->
# <tr>
# <td class="text-center text-uppercase overall-odds" colspan="3" data-bind="visible: odds.overallOdds, html: 'Overall Odds '+odds.overallOdds">Overall Odds 4.71</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# ********************
# <div class="row scratch-game pad50 mg0">
# <div class="col-md-12 mgb20 pd0">
# <span class="text-uppercase bold new pull-left" data-bind="visible: isNewGame == 1" style="display: none;"> New!</span>
# <span class="scratch-game-title cr-main text-uppercase pull-left" data-bind="html: gameName">Gnome Me The Money</span>
# </div>
# <div class="col-md-6 left">
# <div class="scratch-game-img-container mgb20" data-bind="if:visibleImage()!=''">
# <img alt="Gnome Me The Money" data-bind="click: imageFaceToggle, attr: { src: visibleImage, alt: name }" src="/static/assets/1174_front.png"/>
# </div>
# <label class="cr-main font15 text-uppercase mgb10 pointer" data-bind="click: imageFaceToggle">CLICK FOR TICKET BACK</label>
# <div class="scratch-game-description" data-bind="html: howToPlay"><p>Match any of YOUR NUMBERS to either WINNING NUMBER, win prize shown for that number. Reveal a GNOME symbol, win prize shown under that symbol instantly.</p>
# </div>
# </div>
# <!-- GAME ODDS -->
# <div class="col-md-6 pd0">
# <table>
# <thead class="bgg-secondary">
# <tr>
# <th class="text-center text-uppercase">Win</th>
# <th class="text-center text-uppercase cr-main">Prize</th>
# <th class="text-center text-uppercase">Odds</th>
# </tr>
# </thead>
# <tbody>
# <!-- ko foreach: odds.gameTable -->
# <tr>
# <td class="text-center" data-bind="text: win">$1</td>
# <td class="text-center cr-main" data-bind="text: prize">$1</td>
# <td class="text-center" data-bind="text: odds">1:7.69</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$2</td>
# <td class="text-center cr-main" data-bind="text: prize">$2</td>
# <td class="text-center" data-bind="text: odds">1:17.39</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5</td>
# <td class="text-center cr-main" data-bind="text: prize">$5</td>
# <td class="text-center" data-bind="text: odds">1:66.67</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5 x 2</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:200.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:200.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$20</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:666.67</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5 x 4</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:1,333.33</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$40</td>
# <td class="text-center cr-main" data-bind="text: prize">$40</td>
# <td class="text-center" data-bind="text: odds">1:1,666.67</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10 x 4</td>
# <td class="text-center cr-main" data-bind="text: prize">$40</td>
# <td class="text-center" data-bind="text: odds">1:1,333.33</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">($40 x 2) + ($10 x 2)</td>
# <td class="text-center cr-main" data-bind="text: prize">$100</td>
# <td class="text-center" data-bind="text: odds">1:4,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$100</td>
# <td class="text-center cr-main" data-bind="text: prize">$100</td>
# <td class="text-center" data-bind="text: odds">1:4,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$1,000</td>
# <td class="text-center cr-main" data-bind="text: prize">$1,000</td>
# <td class="text-center" data-bind="text: odds">1:110,000.00</td>
# </tr>
# <!-- /ko -->
# <tr>
# <td class="text-center text-uppercase overall-odds" colspan="3" data-bind="visible: odds.overallOdds, html: 'Overall Odds '+odds.overallOdds">Overall Odds 4.62</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# ********************
# <div class="row scratch-game pad50 mg0">
# <div class="col-md-12 mgb20 pd0">
# <span class="text-uppercase bold new pull-left" data-bind="visible: isNewGame == 1" style="display: none;"> New!</span>
# <span class="scratch-game-title cr-main text-uppercase pull-left" data-bind="html: gameName">Lucky Roll</span>
# </div>
# <div class="col-md-6 left">
# <div class="scratch-game-img-container mgb20" data-bind="if:visibleImage()!=''">
# <img alt="Lucky Roll" data-bind="click: imageFaceToggle, attr: { src: visibleImage, alt: name }" src="/static/assets/1173_front.png"/>
# </div>
# <label class="cr-main font15 text-uppercase mgb10 pointer" data-bind="click: imageFaceToggle">CLICK FOR TICKET BACK</label>
# <div class="scratch-game-description" data-bind="html: howToPlay"><p>If any one ROLL adds up to 7, win prize for that ROLL.</p>
# <p>If any one ROLL adds up to 11, win DOUBLE the prize for that ROLL!</p>
# </div>
# </div>
# <!-- GAME ODDS -->
# <div class="col-md-6 pd0">
# <table>
# <thead class="bgg-secondary">
# <tr>
# <th class="text-center text-uppercase">Win</th>
# <th class="text-center text-uppercase cr-main">Prize</th>
# <th class="text-center text-uppercase">Odds</th>
# </tr>
# </thead>
# <tbody>
# <!-- ko foreach: odds.gameTable -->
# <tr>
# <td class="text-center" data-bind="text: win">$1</td>
# <td class="text-center cr-main" data-bind="text: prize">$1</td>
# <td class="text-center" data-bind="text: odds">1:7.69</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$2</td>
# <td class="text-center cr-main" data-bind="text: prize">$2</td>
# <td class="text-center" data-bind="text: odds">1:18.18</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5</td>
# <td class="text-center cr-main" data-bind="text: prize">$5</td>
# <td class="text-center" data-bind="text: odds">1:100.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5 w/DOUBLE</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:200.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:200.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10 w/DOUBLE</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:571.43</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$20</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:1,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$20 w/DOUBLE</td>
# <td class="text-center cr-main" data-bind="text: prize">$40</td>
# <td class="text-center" data-bind="text: odds">1:571.43</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$40</td>
# <td class="text-center cr-main" data-bind="text: prize">$40</td>
# <td class="text-center" data-bind="text: odds">1:2,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$100</td>
# <td class="text-center cr-main" data-bind="text: prize">$100</td>
# <td class="text-center" data-bind="text: odds">1:4,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$2,000</td>
# <td class="text-center cr-main" data-bind="text: prize">$2,000</td>
# <td class="text-center" data-bind="text: odds">1:110,000.00</td>
# </tr>
# <!-- /ko -->
# <tr>
# <td class="text-center text-uppercase overall-odds" colspan="3" data-bind="visible: odds.overallOdds, html: 'Overall Odds '+odds.overallOdds">Overall Odds 4.76</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# ********************
# <div class="row scratch-game pad50 mg0">
# <div class="col-md-12 mgb20 pd0">
# <span class="text-uppercase bold new pull-left" data-bind="visible: isNewGame == 1" style="display: none;"> New!</span>
# <span class="scratch-game-title cr-main text-uppercase pull-left" data-bind="html: gameName">Lucky Spot</span>
# </div>
# <div class="col-md-6 left">
# <div class="scratch-game-img-container mgb20" data-bind="if:visibleImage()!=''">
# <img alt="Lucky Spot" data-bind="click: imageFaceToggle, attr: { src: visibleImage, alt: name }" src="/static/assets/1167_front.png"/>
# </div>
# <label class="cr-main font15 text-uppercase mgb10 pointer" data-bind="click: imageFaceToggle">CLICK FOR TICKET BACK</label>
# <div class="scratch-game-description" data-bind="html: howToPlay"><p>Reveal a prize amount in any of the four LUCKY SPOTS, WIN that amount.</p>
# </div>
# </div>
# <!-- GAME ODDS -->
# <div class="col-md-6 pd0">
# <table>
# <thead class="bgg-secondary">
# <tr>
# <th class="text-center text-uppercase">Win</th>
# <th class="text-center text-uppercase cr-main">Prize</th>
# <th class="text-center text-uppercase">Odds</th>
# </tr>
# </thead>
# <tbody>
# <!-- ko foreach: odds.gameTable -->
# <tr>
# <td class="text-center" data-bind="text: win">$1</td>
# <td class="text-center cr-main" data-bind="text: prize">$1</td>
# <td class="text-center" data-bind="text: odds">1:7.69</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$1 x 2</td>
# <td class="text-center cr-main" data-bind="text: prize">$2</td>
# <td class="text-center" data-bind="text: odds">1:33.33</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$2</td>
# <td class="text-center cr-main" data-bind="text: prize">$2</td>
# <td class="text-center" data-bind="text: odds">1:50.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">($2 x 2) + $1</td>
# <td class="text-center cr-main" data-bind="text: prize">$5</td>
# <td class="text-center" data-bind="text: odds">1:100.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5</td>
# <td class="text-center cr-main" data-bind="text: prize">$5</td>
# <td class="text-center" data-bind="text: odds">1:100.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5 x 2</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:400.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:400.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5 x 4</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:333.33</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10 x 2</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:333.33</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$20</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:666.67</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">($20 x 2) + ($5 x 2)</td>
# <td class="text-center cr-main" data-bind="text: prize">$50</td>
# <td class="text-center" data-bind="text: odds">1:3,333.33</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$50</td>
# <td class="text-center cr-main" data-bind="text: prize">$50</td>
# <td class="text-center" data-bind="text: odds">1:3,333.33</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$100</td>
# <td class="text-center cr-main" data-bind="text: prize">$100</td>
# <td class="text-center" data-bind="text: odds">1:20,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$1,000</td>
# <td class="text-center cr-main" data-bind="text: prize">$1,000</td>
# <td class="text-center" data-bind="text: odds">1:73,333.33</td>
# </tr>
# <!-- /ko -->
# <tr>
# <td class="text-center text-uppercase overall-odds" colspan="3" data-bind="visible: odds.overallOdds, html: 'Overall Odds '+odds.overallOdds">Overall Odds 4.69</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# ********************
# <div class="row scratch-game pad50 mg0">
# <div class="col-md-12 mgb20 pd0">
# <span class="text-uppercase bold new pull-left" data-bind="visible: isNewGame == 1" style="display: none;"> New!</span>
# <span class="scratch-game-title cr-main text-uppercase pull-left" data-bind="html: gameName">Merry Christmas</span>
# </div>
# <div class="col-md-6 left">
# <div class="scratch-game-img-container mgb20" data-bind="if:visibleImage()!=''">
# <img alt="Merry Christmas" data-bind="click: imageFaceToggle, attr: { src: visibleImage, alt: name }" src="/static/assets/1161_front.png"/>
# </div>
# <label class="cr-main font15 text-uppercase mgb10 pointer" data-bind="click: imageFaceToggle">CLICK FOR TICKET BACK</label>
# <div class="scratch-game-description" data-bind="html: howToPlay"><p>Get a "CANDY CANE" symbol, WIN prize shown for that symbol.</p>
# </div>
# </div>
# <!-- GAME ODDS -->
# <div class="col-md-6 pd0">
# <table>
# <thead class="bgg-secondary">
# <tr>
# <th class="text-center text-uppercase">Win</th>
# <th class="text-center text-uppercase cr-main">Prize</th>
# <th class="text-center text-uppercase">Odds</th>
# </tr>
# </thead>
# <tbody>
# <!-- ko foreach: odds.gameTable -->
# <tr>
# <td class="text-center" data-bind="text: win">$1</td>
# <td class="text-center cr-main" data-bind="text: prize">$1</td>
# <td class="text-center" data-bind="text: odds">1:6.25</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$2</td>
# <td class="text-center cr-main" data-bind="text: prize">$1</td>
# <td class="text-center" data-bind="text: odds">1:21.05</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5</td>
# <td class="text-center cr-main" data-bind="text: prize">$5</td>
# <td class="text-center" data-bind="text: odds">1:66.67</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5 x 2</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:133.33</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:133.33</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$20</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:1,052.63</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5 x 4</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:1,052:63</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$40</td>
# <td class="text-center cr-main" data-bind="text: prize">$40</td>
# <td class="text-center" data-bind="text: odds">1:4,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">($5 x 4) + ($10 x 2)</td>
# <td class="text-center cr-main" data-bind="text: prize">$40</td>
# <td class="text-center" data-bind="text: odds">1:4,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">($20 x 4) + ($10 x 2)</td>
# <td class="text-center cr-main" data-bind="text: prize">$100</td>
# <td class="text-center" data-bind="text: odds">1:8,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$100</td>
# <td class="text-center cr-main" data-bind="text: prize">$100</td>
# <td class="text-center" data-bind="text: odds">1:8,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$1,000</td>
# <td class="text-center cr-main" data-bind="text: prize">$1,000</td>
# <td class="text-center" data-bind="text: odds">1:60,000.00</td>
# </tr>
# <!-- /ko -->
# <tr>
# <td class="text-center text-uppercase overall-odds" colspan="3" data-bind="visible: odds.overallOdds, html: 'Overall Odds '+odds.overallOdds">Overall Odds 4.16</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# ********************
# <div class="row scratch-game pad50 mg0">
# <div class="col-md-12 mgb20 pd0">
# <span class="text-uppercase bold new pull-left" data-bind="visible: isNewGame == 1" style="display: none;"> New!</span>
# <span class="scratch-game-title cr-main text-uppercase pull-left" data-bind="html: gameName">Snow Days</span>
# </div>
# <div class="col-md-6 left">
# <div class="scratch-game-img-container mgb20" data-bind="if:visibleImage()!=''">
# <img alt="Snow Days" data-bind="click: imageFaceToggle, attr: { src: visibleImage, alt: name }" src="/static/assets/1162_front.png"/>
# </div>
# <label class="cr-main font15 text-uppercase mgb10 pointer" data-bind="click: imageFaceToggle">CLICK FOR TICKET BACK</label>
# <div class="scratch-game-description" data-bind="html: howToPlay"><p>Match any of YOUR SYMBOLS to the WINNING SYMBOL, win prize shown for that symbol.</p>
# </div>
# </div>
# <!-- GAME ODDS -->
# <div class="col-md-6 pd0">
# <table>
# <thead class="bgg-secondary">
# <tr>
# <th class="text-center text-uppercase">Win</th>
# <th class="text-center text-uppercase cr-main">Prize</th>
# <th class="text-center text-uppercase">Odds</th>
# </tr>
# </thead>
# <tbody>
# <!-- ko foreach: odds.gameTable -->
# <tr>
# <td class="text-center" data-bind="text: win">$1</td>
# <td class="text-center cr-main" data-bind="text: prize">$1</td>
# <td class="text-center" data-bind="text: odds">1:7.14</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$1 x 2</td>
# <td class="text-center cr-main" data-bind="text: prize">$2</td>
# <td class="text-center" data-bind="text: odds">1:50.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$2</td>
# <td class="text-center cr-main" data-bind="text: prize">$2</td>
# <td class="text-center" data-bind="text: odds">1:50.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5</td>
# <td class="text-center cr-main" data-bind="text: prize">$5</td>
# <td class="text-center" data-bind="text: odds">1:66.67</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5 x 2</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:200.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:200.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5 + $10</td>
# <td class="text-center cr-main" data-bind="text: prize">$15</td>
# <td class="text-center" data-bind="text: odds">1:400.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$15</td>
# <td class="text-center cr-main" data-bind="text: prize">$15</td>
# <td class="text-center" data-bind="text: odds">1:400.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5 x 4</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:1,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$20</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:1,333.33</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10 x 5</td>
# <td class="text-center cr-main" data-bind="text: prize">$50</td>
# <td class="text-center" data-bind="text: odds">1:4,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$50</td>
# <td class="text-center cr-main" data-bind="text: prize">$50</td>
# <td class="text-center" data-bind="text: odds">1:4,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$50 x 2</td>
# <td class="text-center cr-main" data-bind="text: prize">$100</td>
# <td class="text-center" data-bind="text: odds">1:20,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$100</td>
# <td class="text-center cr-main" data-bind="text: prize">$100</td>
# <td class="text-center" data-bind="text: odds">1:20,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$1,500</td>
# <td class="text-center cr-main" data-bind="text: prize">$1,500</td>
# <td class="text-center" data-bind="text: odds">1:60,000.00</td>
# </tr>
# <!-- /ko -->
# <tr>
# <td class="text-center text-uppercase overall-odds" colspan="3" data-bind="visible: odds.overallOdds, html: 'Overall Odds '+odds.overallOdds">Overall Odds 4.71</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# ********************
# <div class="row scratch-game pad50 mg0">
# <div class="col-md-12 mgb20 pd0">
# <span class="text-uppercase bold new pull-left" data-bind="visible: isNewGame == 1" style="display: none;"> New!</span>
# <span class="scratch-game-title cr-main text-uppercase pull-left" data-bind="html: gameName">E-I-E-I DOUGH</span>
# </div>
# <div class="col-md-6 left">
# <div class="scratch-game-img-container mgb20" data-bind="if:visibleImage()!=''">
# <img alt="E-I-E-I DOUGH" data-bind="click: imageFaceToggle, attr: { src: visibleImage, alt: name }" src="/static/assets/1154_front.png"/>
# </div>
# <label class="cr-main font15 text-uppercase mgb10 pointer" data-bind="click: imageFaceToggle">CLICK FOR TICKET BACK</label>
# <div class="scratch-game-description" data-bind="html: howToPlay"><p>Match 3 LIKE amounts, WIN that amount. Reveal a TRACTOR symbol in the BONUS BARN, instantly WIN prize shown.</p>
# </div>
# </div>
# <!-- GAME ODDS -->
# <div class="col-md-6 pd0">
# <table>
# <thead class="bgg-secondary">
# <tr>
# <th class="text-center text-uppercase">Win</th>
# <th class="text-center text-uppercase cr-main">Prize</th>
# <th class="text-center text-uppercase">Odds</th>
# </tr>
# </thead>
# <tbody>
# <!-- ko foreach: odds.gameTable -->
# <tr>
# <td class="text-center" data-bind="text: win">$1</td>
# <td class="text-center cr-main" data-bind="text: prize">$1</td>
# <td class="text-center" data-bind="text: odds">1:7.69</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$2</td>
# <td class="text-center cr-main" data-bind="text: prize">$2</td>
# <td class="text-center" data-bind="text: odds">1:18.18</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5</td>
# <td class="text-center cr-main" data-bind="text: prize">$5</td>
# <td class="text-center" data-bind="text: odds">1:100.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10 w/TRACTOR</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:200.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:200.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$20 w/TRACTOR</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:500.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$20</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:1,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$50 w/TRACTOR</td>
# <td class="text-center cr-main" data-bind="text: prize">$50</td>
# <td class="text-center" data-bind="text: odds">1:740.74</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$50</td>
# <td class="text-center cr-main" data-bind="text: prize">$50</td>
# <td class="text-center" data-bind="text: odds">1:2,857.14</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$100</td>
# <td class="text-center cr-main" data-bind="text: prize">$100</td>
# <td class="text-center" data-bind="text: odds">1:2,857.14</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$1,000</td>
# <td class="text-center cr-main" data-bind="text: prize">$1,000</td>
# <td class="text-center" data-bind="text: odds">1:110,000.00</td>
# </tr>
# <!-- /ko -->
# <tr>
# <td class="text-center text-uppercase overall-odds" colspan="3" data-bind="visible: odds.overallOdds, html: 'Overall Odds '+odds.overallOdds">Overall Odds 4.76</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# ********************
# <div class="row scratch-game pad50 mg0">
# <div class="col-md-12 mgb20 pd0">
# <span class="text-uppercase bold new pull-left" data-bind="visible: isNewGame == 1" style="display: none;"> New!</span>
# <span class="scratch-game-title cr-main text-uppercase pull-left" data-bind="html: gameName">Crossword Express</span>
# </div>
# <div class="col-md-6 left">
# <div class="scratch-game-img-container mgb20" data-bind="if:visibleImage()!=''">
# <img alt="1143- Crossword Express" data-bind="click: imageFaceToggle, attr: { src: visibleImage, alt: name }" src="/static/assets/1143-_Crossword_Express_Front.png"/>
# </div>
# <label class="cr-main font15 text-uppercase mgb10 pointer" data-bind="click: imageFaceToggle">CLICK FOR TICKET BACK</label>
# <div class="scratch-game-description" data-bind="html: howToPlay"><p>Scratch "YOUR 18 LETTERS" Box to reveal your 18 letters. Scratch the corresponding letters on the CROSSWORD PUZZLE. If you uncover 2 or more complete words in the CROSSWORD PUZZLE, you win the prize indicated in the PRIZE KEY. </p>
# <p>Letters forming a word filling a complete word space can only be used to form one complete WORD (e.g. "BIG" and "HORN" within "BIGHORN" are consided only one complete WORD). Only highest prize won paid per ticket.</p>
# </div>
# </div>
# <!-- GAME ODDS -->
# <div class="col-md-6 pd0">
# <table>
# <thead class="bgg-secondary">
# <tr>
# <th class="text-center text-uppercase">Win</th>
# <th class="text-center text-uppercase cr-main">Prize</th>
# <th class="text-center text-uppercase">Odds</th>
# </tr>
# </thead>
# <tbody>
# <!-- ko foreach: odds.gameTable -->
# <tr>
# <td class="text-center" data-bind="text: win">2 Words</td>
# <td class="text-center cr-main" data-bind="text: prize">$1</td>
# <td class="text-center" data-bind="text: odds">1:5.26</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">3 Words</td>
# <td class="text-center cr-main" data-bind="text: prize">$3</td>
# <td class="text-center" data-bind="text: odds">1:25.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">4 Words</td>
# <td class="text-center cr-main" data-bind="text: prize">$12</td>
# <td class="text-center" data-bind="text: odds">1:50.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">5 Words</td>
# <td class="text-center cr-main" data-bind="text: prize">$40</td>
# <td class="text-center" data-bind="text: odds">1:6,666.67</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">6 Words</td>
# <td class="text-center cr-main" data-bind="text: prize">$1,000</td>
# <td class="text-center" data-bind="text: odds">1:110,000.00</td>
# </tr>
# <!-- /ko -->
# <tr>
# <td class="text-center text-uppercase overall-odds" colspan="3" data-bind="visible: odds.overallOdds, html: 'Overall Odds '+odds.overallOdds">Overall Odds 1:4.00</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# ********************
# <div class="row scratch-game pad50 mg0">
# <div class="col-md-12 mgb20 pd0">
# <span class="text-uppercase bold new pull-left" data-bind="visible: isNewGame == 1" style="display: none;"> New!</span>
# <span class="scratch-game-title cr-main text-uppercase pull-left" data-bind="html: gameName">Super Hot 7's</span>
# </div>
# <div class="col-md-6 left">
# <div class="scratch-game-img-container mgb20" data-bind="if:visibleImage()!=''">
# <img alt="Super Hot 7s" data-bind="click: imageFaceToggle, attr: { src: visibleImage, alt: name }" src="/static/assets/1140_front.png"/>
# </div>
# <label class="cr-main font15 text-uppercase mgb10 pointer" data-bind="click: imageFaceToggle">CLICK FOR TICKET BACK</label>
# <div class="scratch-game-description" data-bind="html: howToPlay"><p>Reveal a "7" symbol, win prize shown.</p>
# </div>
# </div>
# <!-- GAME ODDS -->
# <div class="col-md-6 pd0">
# <table>
# <thead class="bgg-secondary">
# <tr>
# <th class="text-center text-uppercase">Win</th>
# <th class="text-center text-uppercase cr-main">Prize</th>
# <th class="text-center text-uppercase">Odds</th>
# </tr>
# </thead>
# <tbody>
# <!-- ko foreach: odds.gameTable -->
# <tr>
# <td class="text-center" data-bind="text: win">$1</td>
# <td class="text-center cr-main" data-bind="text: prize">$1</td>
# <td class="text-center" data-bind="text: odds">1:7.69</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$1 x 2</td>
# <td class="text-center cr-main" data-bind="text: prize">$2</td>
# <td class="text-center" data-bind="text: odds">1:25.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$2</td>
# <td class="text-center cr-main" data-bind="text: prize">$2</td>
# <td class="text-center" data-bind="text: odds">1:25.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">($2 x 3) + $1</td>
# <td class="text-center cr-main" data-bind="text: prize">$7</td>
# <td class="text-center" data-bind="text: odds">1:80.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$7</td>
# <td class="text-center cr-main" data-bind="text: prize">$7</td>
# <td class="text-center" data-bind="text: odds">1:80.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">($7 x 2) + $2 + $1</td>
# <td class="text-center cr-main" data-bind="text: prize">$17</td>
# <td class="text-center" data-bind="text: odds">1:400.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$17</td>
# <td class="text-center cr-main" data-bind="text: prize">$17</td>
# <td class="text-center" data-bind="text: odds">1:400.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">($7 x 3) + ($2 x 3)</td>
# <td class="text-center cr-main" data-bind="text: prize">$27</td>
# <td class="text-center" data-bind="text: odds">1:2,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$27</td>
# <td class="text-center cr-main" data-bind="text: prize">$27</td>
# <td class="text-center" data-bind="text: odds">1:2,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$70</td>
# <td class="text-center cr-main" data-bind="text: prize">$70</td>
# <td class="text-center" data-bind="text: odds">1:8,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$7,777</td>
# <td class="text-center cr-main" data-bind="text: prize">$7,777</td>
# <td class="text-center" data-bind="text: odds">1:160,000.00</td>
# </tr>
# <!-- /ko -->
# <tr>
# <td class="text-center text-uppercase overall-odds" colspan="3" data-bind="visible: odds.overallOdds, html: 'Overall Odds '+odds.overallOdds">Overall Odds 4.15</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# ********************
# <div class="row scratch-game pad50 mg0">
# <div class="col-md-12 mgb20 pd0">
# <span class="text-uppercase bold new pull-left" data-bind="visible: isNewGame == 1" style="display: none;"> New!</span>
# <span class="scratch-game-title cr-main text-uppercase pull-left" data-bind="html: gameName">Cash Dash</span>
# </div>
# <div class="col-md-6 left">
# <div class="scratch-game-img-container mgb20" data-bind="if:visibleImage()!=''">
# <img alt="Cash Dash" data-bind="click: imageFaceToggle, attr: { src: visibleImage, alt: name }" src="/static/assets/1148_front.png"/>
# </div>
# <label class="cr-main font15 text-uppercase mgb10 pointer" data-bind="click: imageFaceToggle">CLICK FOR TICKET BACK</label>
# <div class="scratch-game-description" data-bind="html: howToPlay"><p>Reveal 3 like symbols. WIN prize shown in PRIZE CIRCLE.</p>
# </div>
# </div>
# <!-- GAME ODDS -->
# <div class="col-md-6 pd0">
# <table>
# <thead class="bgg-secondary">
# <tr>
# <th class="text-center text-uppercase">Win</th>
# <th class="text-center text-uppercase cr-main">Prize</th>
# <th class="text-center text-uppercase">Odds</th>
# </tr>
# </thead>
# <tbody>
# <!-- ko foreach: odds.gameTable -->
# <tr>
# <td class="text-center" data-bind="text: win">$1</td>
# <td class="text-center cr-main" data-bind="text: prize">$1</td>
# <td class="text-center" data-bind="text: odds">1:7.69</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$2</td>
# <td class="text-center cr-main" data-bind="text: prize">$2</td>
# <td class="text-center" data-bind="text: odds">1:18.18</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5</td>
# <td class="text-center cr-main" data-bind="text: prize">$5</td>
# <td class="text-center" data-bind="text: odds">1:100.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:100.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$20</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:444.44</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$50</td>
# <td class="text-center cr-main" data-bind="text: prize">$50</td>
# <td class="text-center" data-bind="text: odds">1:1,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$100</td>
# <td class="text-center cr-main" data-bind="text: prize">$100</td>
# <td class="text-center" data-bind="text: odds">1:1,333.33</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$2,000</td>
# <td class="text-center cr-main" data-bind="text: prize">$2,000</td>
# <td class="text-center" data-bind="text: odds">1:110,000.00</td>
# </tr>
# <!-- /ko -->
# <tr>
# <td class="text-center text-uppercase overall-odds" colspan="3" data-bind="visible: odds.overallOdds, html: 'Overall Odds '+odds.overallOdds">Overall Odds 4.78</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# ********************
# <div class="row scratch-game pad50 mg0">
# <div class="col-md-12 mgb20 pd0">
# <span class="text-uppercase bold new pull-left" data-bind="visible: isNewGame == 1" style="display: none;"> New!</span>
# <span class="scratch-game-title cr-main text-uppercase pull-left" data-bind="html: gameName">Fast Money</span>
# </div>
# <div class="col-md-6 left">
# <div class="scratch-game-img-container mgb20" data-bind="if:visibleImage()!=''">
# <img alt="Fast Money" data-bind="click: imageFaceToggle, attr: { src: visibleImage, alt: name }" src="/static/assets/1126_front.png"/>
# </div>
# <label class="cr-main font15 text-uppercase mgb10 pointer" data-bind="click: imageFaceToggle">CLICK FOR TICKET BACK</label>
# <div class="scratch-game-description" data-bind="html: howToPlay"><p>Reveal a STAR symbol, instantly WIN prize shown.</p>
# </div>
# </div>
# <!-- GAME ODDS -->
# <div class="col-md-6 pd0">
# <table>
# <thead class="bgg-secondary">
# <tr>
# <th class="text-center text-uppercase">Win</th>
# <th class="text-center text-uppercase cr-main">Prize</th>
# <th class="text-center text-uppercase">Odds</th>
# </tr>
# </thead>
# <tbody>
# <!-- ko foreach: odds.gameTable -->
# <tr>
# <td class="text-center" data-bind="text: win">$1</td>
# <td class="text-center cr-main" data-bind="text: prize">$1</td>
# <td class="text-center" data-bind="text: odds">1:7.14</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$1 x 2</td>
# <td class="text-center cr-main" data-bind="text: prize">$2</td>
# <td class="text-center" data-bind="text: odds">1:50.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$2</td>
# <td class="text-center cr-main" data-bind="text: prize">$2</td>
# <td class="text-center" data-bind="text: odds">1:50.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">Fast Bonus Game: $5</td>
# <td class="text-center cr-main" data-bind="text: prize">$5</td>
# <td class="text-center" data-bind="text: odds">1:66.67</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5 x 2</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:200.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">Fast Bonus Game: $10</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:200.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5 + $10</td>
# <td class="text-center cr-main" data-bind="text: prize">$15</td>
# <td class="text-center" data-bind="text: odds">1:400.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$15</td>
# <td class="text-center cr-main" data-bind="text: prize">$15</td>
# <td class="text-center" data-bind="text: odds">1:400.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">Fast Bonus Game: $20</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:666.67</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$20</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:2,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10 x 5</td>
# <td class="text-center cr-main" data-bind="text: prize">$50</td>
# <td class="text-center" data-bind="text: odds">1:1,818.18</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$50</td>
# <td class="text-center cr-main" data-bind="text: prize">$50</td>
# <td class="text-center" data-bind="text: odds">1:4,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$20 x 5</td>
# <td class="text-center cr-main" data-bind="text: prize">$100</td>
# <td class="text-center" data-bind="text: odds">1:10,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$100</td>
# <td class="text-center cr-main" data-bind="text: prize">$100</td>
# <td class="text-center" data-bind="text: odds">1:20,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$1,500</td>
# <td class="text-center cr-main" data-bind="text: prize">$1,500</td>
# <td class="text-center" data-bind="text: odds">1:110,000.00</td>
# </tr>
# <!-- /ko -->
# <tr>
# <td class="text-center text-uppercase overall-odds" colspan="3" data-bind="visible: odds.overallOdds, html: 'Overall Odds '+odds.overallOdds">Overall Odds 4.70</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# ********************
# <div class="row scratch-game pad50 mg0">
# <div class="col-md-12 mgb20 pd0">
# <span class="text-uppercase bold new pull-left" data-bind="visible: isNewGame == 1" style="display: none;"> New!</span>
# <span class="scratch-game-title cr-main text-uppercase pull-left" data-bind="html: gameName">Super HOT 7's</span>
# </div>
# <div class="col-md-6 left">
# <div class="scratch-game-img-container mgb20" data-bind="if:visibleImage()!=''">
# <img alt="Super HOT 7's" data-bind="click: imageFaceToggle, attr: { src: visibleImage, alt: name }" src="/static/assets/1101_front.jpeg"/>
# </div>
# <label class="cr-main font15 text-uppercase mgb10 pointer" data-bind="click: imageFaceToggle">CLICK FOR TICKET BACK</label>
# <div class="scratch-game-description" data-bind="html: howToPlay"><p>Reveal a "7" symbol, win prize shown.</p>
# </div>
# </div>
# <!-- GAME ODDS -->
# <div class="col-md-6 pd0">
# <table>
# <thead class="bgg-secondary">
# <tr>
# <th class="text-center text-uppercase">Win</th>
# <th class="text-center text-uppercase cr-main">Prize</th>
# <th class="text-center text-uppercase">Odds</th>
# </tr>
# </thead>
# <tbody>
# <!-- ko foreach: odds.gameTable -->
# <tr>
# <td class="text-center" data-bind="text: win">$1</td>
# <td class="text-center cr-main" data-bind="text: prize">$1</td>
# <td class="text-center" data-bind="text: odds">1:7.69</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$1 x 2</td>
# <td class="text-center cr-main" data-bind="text: prize">$2</td>
# <td class="text-center" data-bind="text: odds">1:25.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$2</td>
# <td class="text-center cr-main" data-bind="text: prize">$2</td>
# <td class="text-center" data-bind="text: odds">1:25.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">($2 x 3) + $1</td>
# <td class="text-center cr-main" data-bind="text: prize">$7</td>
# <td class="text-center" data-bind="text: odds">1:80.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$7</td>
# <td class="text-center cr-main" data-bind="text: prize">$7</td>
# <td class="text-center" data-bind="text: odds">1:80.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">($7 x 2) + $2 + $1</td>
# <td class="text-center cr-main" data-bind="text: prize">$17</td>
# <td class="text-center" data-bind="text: odds">1:400.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$17</td>
# <td class="text-center cr-main" data-bind="text: prize">$17</td>
# <td class="text-center" data-bind="text: odds">1:400.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">($7 x 3) + ($2 x 3)</td>
# <td class="text-center cr-main" data-bind="text: prize">$27</td>
# <td class="text-center" data-bind="text: odds">1:1,250.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$27</td>
# <td class="text-center cr-main" data-bind="text: prize">$27</td>
# <td class="text-center" data-bind="text: odds">1:1,304.35</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$70</td>
# <td class="text-center cr-main" data-bind="text: prize">$70</td>
# <td class="text-center" data-bind="text: odds">1:6,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5,000</td>
# <td class="text-center cr-main" data-bind="text: prize">$5,000</td>
# <td class="text-center" data-bind="text: odds">1:180,000.00</td>
# </tr>
# <!-- /ko -->
# <tr>
# <td class="text-center text-uppercase overall-odds" colspan="3" data-bind="visible: odds.overallOdds, html: 'Overall Odds '+odds.overallOdds">Overall Odds 4.14</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# ********************
# <div class="row scratch-game pad50 mg0">
# <div class="col-md-12 mgb20 pd0">
# <span class="text-uppercase bold new pull-left" data-bind="visible: isNewGame == 1" style="display: none;"> New!</span>
# <span class="scratch-game-title cr-main text-uppercase pull-left" data-bind="html: gameName">Fish &amp; Chips</span>
# </div>
# <div class="col-md-6 left">
# <div class="scratch-game-img-container mgb20" data-bind="if:visibleImage()!=''">
# <img alt="Fish and Chips" data-bind="click: imageFaceToggle, attr: { src: visibleImage, alt: name }" src="/static/assets/1120_front.png"/>
# </div>
# <label class="cr-main font15 text-uppercase mgb10 pointer" data-bind="click: imageFaceToggle">CLICK FOR TICKET BACK</label>
# <div class="scratch-game-description" data-bind="html: howToPlay"><p>Match any of YOUR NUMBERS to either of the WINNING NUMBERS, win PRIZE shown for that number.</p>
# </div>
# </div>
# <!-- GAME ODDS -->
# <div class="col-md-6 pd0">
# <table>
# <thead class="bgg-secondary">
# <tr>
# <th class="text-center text-uppercase">Win</th>
# <th class="text-center text-uppercase cr-main">Prize</th>
# <th class="text-center text-uppercase">Odds</th>
# </tr>
# </thead>
# <tbody>
# <!-- ko foreach: odds.gameTable -->
# <tr>
# <td class="text-center" data-bind="text: win">$1</td>
# <td class="text-center cr-main" data-bind="text: prize">$1</td>
# <td class="text-center" data-bind="text: odds">1:7.69</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$2</td>
# <td class="text-center cr-main" data-bind="text: prize">$2</td>
# <td class="text-center" data-bind="text: odds">1:17.39</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5</td>
# <td class="text-center cr-main" data-bind="text: prize">$5</td>
# <td class="text-center" data-bind="text: odds">1:66.67</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5 x 2</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:200.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:200.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$20</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:666.67</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5 x 4</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:1,333.33</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$40</td>
# <td class="text-center cr-main" data-bind="text: prize">$40</td>
# <td class="text-center" data-bind="text: odds">1:1,666.67</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10 x 4</td>
# <td class="text-center cr-main" data-bind="text: prize">$40</td>
# <td class="text-center" data-bind="text: odds">1:1,333.33</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">($40 x 2) + ($10 x 2)</td>
# <td class="text-center cr-main" data-bind="text: prize">$100</td>
# <td class="text-center" data-bind="text: odds">1:4,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$100</td>
# <td class="text-center cr-main" data-bind="text: prize">$100</td>
# <td class="text-center" data-bind="text: odds">1:4,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$1,000</td>
# <td class="text-center cr-main" data-bind="text: prize">$1,000</td>
# <td class="text-center" data-bind="text: odds">1:110,000.00</td>
# </tr>
# <!-- /ko -->
# <tr>
# <td class="text-center text-uppercase overall-odds" colspan="3" data-bind="visible: odds.overallOdds, html: 'Overall Odds '+odds.overallOdds">Overall Odds 4.62</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# ********************
# <div class="row scratch-game pad50 mg0">
# <div class="col-md-12 mgb20 pd0">
# <span class="text-uppercase bold new pull-left" data-bind="visible: isNewGame == 1" style="display: none;"> New!</span>
# <span class="scratch-game-title cr-main text-uppercase pull-left" data-bind="html: gameName">PAYDAY</span>
# </div>
# <div class="col-md-6 left">
# <div class="scratch-game-img-container mgb20" data-bind="if:visibleImage()!=''">
# <img alt="Payday" data-bind="click: imageFaceToggle, attr: { src: visibleImage, alt: name }" src="/static/assets/1117_front.png"/>
# </div>
# <label class="cr-main font15 text-uppercase mgb10 pointer" data-bind="click: imageFaceToggle">CLICK FOR TICKET BACK</label>
# <div class="scratch-game-description" data-bind="html: howToPlay"><p>Reveal a money bag symbol in any of "YOUR PAYDAYS", win prize shown. Reveal a "2X" symbol and win DOUBLE the prize shown.</p>
# </div>
# </div>
# <!-- GAME ODDS -->
# <div class="col-md-6 pd0">
# <table>
# <thead class="bgg-secondary">
# <tr>
# <th class="text-center text-uppercase">Win</th>
# <th class="text-center text-uppercase cr-main">Prize</th>
# <th class="text-center text-uppercase">Odds</th>
# </tr>
# </thead>
# <tbody>
# <!-- ko foreach: odds.gameTable -->
# <tr>
# <td class="text-center" data-bind="text: win">$1</td>
# <td class="text-center cr-main" data-bind="text: prize">$1</td>
# <td class="text-center" data-bind="text: odds">1:7.69</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$1 w/Doubler</td>
# <td class="text-center cr-main" data-bind="text: prize">$2</td>
# <td class="text-center" data-bind="text: odds">1:33.33</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$2</td>
# <td class="text-center cr-main" data-bind="text: prize">$2</td>
# <td class="text-center" data-bind="text: odds">1:50.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$1 x 5</td>
# <td class="text-center cr-main" data-bind="text: prize">$5</td>
# <td class="text-center" data-bind="text: odds">1:100.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$2 w/Doubler + $1</td>
# <td class="text-center cr-main" data-bind="text: prize">$5</td>
# <td class="text-center" data-bind="text: odds">1:100.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5 w/Doubler</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:400.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:400.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10 w/Doubler</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:333.33</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5 w/Doubler + $10</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:333.33</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$20</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:666.67</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10 x 5</td>
# <td class="text-center cr-main" data-bind="text: prize">$50</td>
# <td class="text-center" data-bind="text: odds">1:3,333.33</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$50</td>
# <td class="text-center cr-main" data-bind="text: prize">$50</td>
# <td class="text-center" data-bind="text: odds">1:3,333.33</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$100</td>
# <td class="text-center cr-main" data-bind="text: prize">$100</td>
# <td class="text-center" data-bind="text: odds">1:20,000.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$1,500</td>
# <td class="text-center cr-main" data-bind="text: prize">$1,500</td>
# <td class="text-center" data-bind="text: odds">1:110,000.00</td>
# </tr>
# <!-- /ko -->
# <tr>
# <td class="text-center text-uppercase overall-odds" colspan="3" data-bind="visible: odds.overallOdds, html: 'Overall Odds '+odds.overallOdds">Overall Odds 4.69</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# ********************
# <div class="row scratch-game pad50 mg0">
# <div class="col-md-12 mgb20 pd0">
# <span class="text-uppercase bold new pull-left" data-bind="visible: isNewGame == 1" style="display: none;"> New!</span>
# <span class="scratch-game-title cr-main text-uppercase pull-left" data-bind="html: gameName">DEUCES WILD</span>
# </div>
# <div class="col-md-6 left">
# <div class="scratch-game-img-container mgb20" data-bind="if:visibleImage()!=''">
# <img alt="Deuces Wild" data-bind="click: imageFaceToggle, attr: { src: visibleImage, alt: name }" src="/static/assets/1109_front.png"/>
# </div>
# <label class="cr-main font15 text-uppercase mgb10 pointer" data-bind="click: imageFaceToggle">CLICK FOR TICKET BACK</label>
# <div class="scratch-game-description" data-bind="html: howToPlay"><p>If YOUR CARD beats the DEALER'S CARD, win prize for that GAME.</p>
# </div>
# </div>
# <!-- GAME ODDS -->
# <div class="col-md-6 pd0">
# <table>
# <thead class="bgg-secondary">
# <tr>
# <th class="text-center text-uppercase">Win</th>
# <th class="text-center text-uppercase cr-main">Prize</th>
# <th class="text-center text-uppercase">Odds</th>
# </tr>
# </thead>
# <tbody>
# <!-- ko foreach: odds.gameTable -->
# <tr>
# <td class="text-center" data-bind="text: win">$1</td>
# <td class="text-center cr-main" data-bind="text: prize">$1</td>
# <td class="text-center" data-bind="text: odds">1:7.69</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$2</td>
# <td class="text-center cr-main" data-bind="text: prize">$2</td>
# <td class="text-center" data-bind="text: odds">1:17.39</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5</td>
# <td class="text-center cr-main" data-bind="text: prize">$5</td>
# <td class="text-center" data-bind="text: odds">1:66.67</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5 w/2</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:200.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:200.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$20</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:1,333.33</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10 w/2</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:666.67</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$40</td>
# <td class="text-center cr-main" data-bind="text: prize">$40</td>
# <td class="text-center" data-bind="text: odds">1:1,666.67</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10 x 4</td>
# <td class="text-center cr-main" data-bind="text: prize">$40</td>
# <td class="text-center" data-bind="text: odds">1:1,666.67</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$50 w/2</td>
# <td class="text-center cr-main" data-bind="text: prize">$100</td>
# <td class="text-center" data-bind="text: odds">1:2,857.14</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$100</td>
# <td class="text-center cr-main" data-bind="text: prize">$100</td>
# <td class="text-center" data-bind="text: odds">1:6,666.67</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$2,000</td>
# <td class="text-center cr-main" data-bind="text: prize">$2,000</td>
# <td class="text-center" data-bind="text: odds">1:110,000.00</td>
# </tr>
# <!-- /ko -->
# <tr>
# <td class="text-center text-uppercase overall-odds" colspan="3" data-bind="visible: odds.overallOdds, html: 'Overall Odds '+odds.overallOdds">Overall Odds 4.62</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# ********************
# <div class="row scratch-game pad50 mg0">
# <div class="col-md-12 mgb20 pd0">
# <span class="text-uppercase bold new pull-left" data-bind="visible: isNewGame == 1" style="display: none;"> New!</span>
# <span class="scratch-game-title cr-main text-uppercase pull-left" data-bind="html: gameName">Moose Money</span>
# </div>
# <div class="col-md-6 left">
# <div class="scratch-game-img-container mgb20" data-bind="if:visibleImage()!=''">
# <img alt="Moose Money" data-bind="click: imageFaceToggle, attr: { src: visibleImage, alt: name }" src="/static/assets/1131_front.png"/>
# </div>
# <label class="cr-main font15 text-uppercase mgb10 pointer" data-bind="click: imageFaceToggle">CLICK FOR TICKET BACK</label>
# <div class="scratch-game-description" data-bind="html: howToPlay"><p>Get 3 like amounts, win that amount.</p>
# </div>
# </div>
# <!-- GAME ODDS -->
# <div class="col-md-6 pd0">
# <table>
# <thead class="bgg-secondary">
# <tr>
# <th class="text-center text-uppercase">Win</th>
# <th class="text-center text-uppercase cr-main">Prize</th>
# <th class="text-center text-uppercase">Odds</th>
# </tr>
# </thead>
# <tbody>
# <!-- ko foreach: odds.gameTable -->
# <tr>
# <td class="text-center" data-bind="text: win">$1</td>
# <td class="text-center cr-main" data-bind="text: prize">$1</td>
# <td class="text-center" data-bind="text: odds">1:7.69</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$2</td>
# <td class="text-center cr-main" data-bind="text: prize">$2</td>
# <td class="text-center" data-bind="text: odds">1:18.18</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$5</td>
# <td class="text-center cr-main" data-bind="text: prize">$5</td>
# <td class="text-center" data-bind="text: odds">1:100.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$10</td>
# <td class="text-center cr-main" data-bind="text: prize">$10</td>
# <td class="text-center" data-bind="text: odds">1:100.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$20</td>
# <td class="text-center cr-main" data-bind="text: prize">$20</td>
# <td class="text-center" data-bind="text: odds">1:400.00</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$50</td>
# <td class="text-center cr-main" data-bind="text: prize">$50</td>
# <td class="text-center" data-bind="text: odds">1:909.09</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$100</td>
# <td class="text-center cr-main" data-bind="text: prize">$100</td>
# <td class="text-center" data-bind="text: odds">1:1,333.33</td>
# </tr>
# <tr>
# <td class="text-center" data-bind="text: win">$1,000</td>
# <td class="text-center cr-main" data-bind="text: prize">$1,000</td>
# <td class="text-center" data-bind="text: odds">1:110,000.00</td>
# </tr>
# <!-- /ko -->
# <tr>
# <td class="text-center text-uppercase overall-odds" colspan="3" data-bind="visible: odds.overallOdds, html: 'Overall Odds '+odds.overallOdds">Overall Odds 4.78</td>
# </tr>
# </tbody>
# </table>
# </div>
# </div>
# ********************
# 16

# %%
tables = output.findAll("table")
games = []
for table in tables:
     if table.findParent("table") is None:
            if table.thead is not None:
                games.append(table)
